# %% [markdown]
# <a href="https://colab.research.google.com/github/cguillermo79/cguillermo2/blob/main/Ing_Ambiental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Malla de la carrera más linda: Ing. Ambiental

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import pandas as pd

# Datos de ejemplo
cursos = {
    'Ciclo 1': ['Cálculo diferencial e integral', 'Biologia', 'Mecánica de fluidos y termodinámica', 'Introducción a la ingeniería ambiental','Química', 'Herramientas informáticas'],
    'Ciclo 2': ['Biología 2', 'Ambiente y Sociedad', 'Física Ambiental', 'Programación y base de datos', 'Ecuaciones diferenciales', '*'],
    'Ciclo 3': ['Microbiología Ambiental', 'Modelación Ambiental', 'Biofísica','Ecología', 'Estadística Descriptiva', '*'],
    'Ciclo 4': ['Tecnologías de información geoespacial', 'Ecología SbN', '(CN)Flora y fauna', 'Energías Renovables', 'Estadística Inferencial', '*'],
    'Ciclo 5': ['Química Ambiental', 'Hidrología y Meteorología', 'Economía Ambiental', 'Ecotoxicología','Educación Ambiental', 'Residuos Sólidos'],
    'Ciclo 6': ['Procesos Ambientales', 'Formulación de proyectos de sustentabilidad ambiental', 'Gestión Ambiental de Cuencas', 'Calidad del agua', 'Calidad del suelo', 'Calidad del aire'],
    'Ciclo 7': [ 'Metodología de la Investigación', 'Evaluación de Impactos Ambientales', 'Lesgislación, Regulación y Fiscalización Ambiental', 'Tecnologías para el tratamiento de aguas','Remediciación de suelo', 'Tratamiento de la contaminación del aire'],
    'Ciclo 8': ['Sistema de Gestión y Auditorías Ambientales', 'Gestión de residuos sólidos', 'Técnicas de Restauración Ambiental','Seguridad y Salud Ocupacional', '', 'Biotecnología y Remediación Ambiental', 'Formulación del proyecto de titulación'],
    'Ciclo 9': ['TIC', 'Humanismo y ética', 'Solución de conflictos ambientales', 'Comunicación Oral y Escrita'],
}

def crear_interfaz():
    # Crear widgets para cada ciclo
    ciclo_widgets = {}

    for ciclo, lista_cursos in cursos.items():
        # Lista de cursos seleccionables
        checklist = widgets.SelectMultiple(
            options=lista_cursos,
            description=ciclo,
            layout=widgets.Layout(width='200px', height='150px')
        )
        ciclo_widgets[ciclo] = checklist

    # Botones para mover cursos
    mover_izq = widgets.Button(description="← Mover")
    mover_der = widgets.Button(description="Mover →")

    # Contenedor principal
    hbox = widgets.HBox(list(ciclo_widgets.values()))

    def mover_derecha(b):
        # Lógica para mover cursos entre ciclos
        pass

    def mover_izquierda(b):
        # Lógica para mover cursos entre ciclos
        pass

    mover_der.on_click(mover_derecha)
    mover_izq.on_click(mover_izquierda)

    display(hbox, widgets.HBox([mover_izq, mover_der]))

crear_interfaz()
# Out:
# HBox(children=(SelectMultiple(description='Ciclo 1', layout=Layout(height='150px', width='200px'), options=('C…
# HBox(children=(Button(description='← Mover', style=ButtonStyle()), Button(description='Mover →', style=ButtonS…
